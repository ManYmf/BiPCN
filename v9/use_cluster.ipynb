# %%
from radas import run_experiment, get_ray_results_dir
import ray.tune as tune
from v91 import trainable
import torch

results = await run_experiment(
    user_name="mengfan",
    experiment_name="换个写法试试",
    param_space=dict(
        epochs = tune.grid_search([100]),

    ),
    # IMPORTANT: when using cluster, your trainable cannot be defined in this script, but has to be defined in a separate file, and imported in this script
    trainable=trainable,
    # When use cluster, local_storage_path needs to be specified in this way
    local_storage_path=get_ray_results_dir(),
    # Specify the cluster to use
    run_with="cluster:atol-gpu-5090",
    # Specify gram per trial
    cpu_per_trial=1,
    # If the gram_per_trial you set is larger than GRAM of a single GPU, you will be allocated with more than one GPUs
    # to fit your need. But in this case, you will need to handle how do you want to distribute your workload to these multiple GPUs
    # To check GRAM of a single GPU, use the following code:
    # from radas.clusters import gram_per_gpu
    #
    runtime_env={
        "pip": ["emoji"],
        # for more runtime_env specifications, see https://docs.ray.io/en/latest/ray-core/handling-dependencies.html#api-reference
    },
    #
    instant_gpu_allocation=1,
)
# Out:
# [INFO]: Checking if the experiment exists...
# [Choices]: Choose an option by number:
# [1]: run -- Run a new experiment (if there is a running experiment, it will be stopped; if there is a existing experiment in the storage, it will be removed)
#  2 : restore -- Restore an existing experiment from the storage (if there is a running experiment, it will be stopped)
#  3 : attach -- Attach to a running experiment
#  4 : stop_attach -- Stop and attach to a running experiment
# >>> [1]: Run a new experiment (if there is a running experiment, it will be stopped; if there is a existing experiment in the storage, it will be removed)
# [INFO]: 🚀 正在测试代理连接...
# [INFO]: ✅ 代理连接成功
# [INFO]: Submitting job...
# 2025-12-15 19:18:51,679	INFO dashboard_sdk.py:355 -- Uploading package gcs://_ray_pkg_0c8fdd0251c90b65.zip.
# 2025-12-15 19:18:51,681	INFO packaging.py:588 -- Creating a file package for local module '/mnt/data/home/mengfan/projects/BiPCN/BiPCN/v9'.
# 2025-12-15 19:18:51,737	INFO dashboard_sdk.py:402 -- Package gcs://_ray_pkg_4588c91f8f921f3a.zip already exists, skipping upload.
# [INFO]: Job submitted.
# [INFO]: Tailing experiment logs below 👇👇👇
# 2025-12-15 06:18:51,716	INFO job_manager.py:531 -- Runtime env is setting up.
#
#   0%|          | 0/10 [00:00<?, ?file/s]
# rm_local_folder: mengfan/换个写法试试/trainable_fec3b_00000_0_2025-12-15_06-12-51/params.pkl:   0%|          | 0/10 [00:00<?, ?file/s]
# rm_local_folder: mengfan/换个写法试试/trainable_fec3b_00000_0_2025-12-15_06-12-51/params.json:   0%|          | 0/10 [00:00<?, ?file/s]
# rm_local_folder: mengfan/换个写法试试/trainable_fec3b_00000_0_2025-12-15_06-12-51/events.out.tfevents.1765797173.atol-gpu-5090-head:   0%|          | 0/10 [00:00<?, ?file/s]
# rm_local_folder: mengfan/换个写法试试/trainable_fec3b_00000_0_2025-12-15_06-12-51/result.json:   0%|          | 0/10 [00:00<?, ?file/s]
# rm_local_folder: mengfan/换个写法试试/trainable_fec3b_00000_0_2025-12-15_06-12-51/progress.csv:   0%|          | 0/10 [00:00<?, ?file/s]
# rm_local_folder: mengfan/换个写法试试/.validate_storage_marker:   0%|          | 0/10 [00:00<?, ?file/s]
# rm_local_folder: mengfan/换个写法试试/tuner.pkl:   0%|          | 0/10 [00:00<?, ?file/s]
# rm_local_folder: mengfan/换个写法试试/experiment_state-2025-12-15_06-12-51.json:   0%|          | 0/10 [00:00<?, ?file/s]
# rm_local_folder: mengfan/换个写法试试/basic-variant-state-2025-12-15_06-12-51.json:   0%|          | 0/10 [00:00<?, ?file/s]
# rm_local_folder: mengfan/换个写法试试/trainable_fec3b_00000_0_2025-12-15_06-12-51:   0%|          | 0/10 [00:00<?, ?file/s]
#
# 2025-12-15 06:19:02,685	INFO worker.py:1627 -- Using address 10.11.0.20:6379 set in the environment variable RAY_ADDRESS
# 2025-12-15 06:19:02,690	INFO worker.py:1768 -- Connecting to existing Ray cluster at address: 10.11.0.20:6379...
# 2025-12-15 06:19:02,710	INFO worker.py:1939 -- Connected to Ray cluster. View the dashboard at http://10.11.0.20:8265
# 2025-12-15 06:19:02,735	INFO tune.py:253 -- Initializing Ray automatically. For cluster usage or custom Ray initialization, call `ray.init(...)` before `Tuner(...)`.
# 2025-12-15 06:19:02,775	WARNING tune_controller.py:2132 -- The maximum number of pending trials has been automatically set to the number of available cluster CPUs, which is high (281 CPUs/pending trials). If you're running an experiment with a large number of trials, this could lead to scheduling overhead. In this case, consider setting the `TUNE_MAX_PENDING_TRIALS_PG` environment variable to the desired maximum number of concurrent pending trials.
# 2025-12-15 06:19:02,779	WARNING tune_controller.py:2132 -- The maximum number of pending trials has been automatically set to the number of available cluster CPUs, which is high (281 CPUs/pending trials). If you're running an experiment with a large number of trials, this could lead to scheduling overhead. In this case, consider setting the `TUNE_MAX_PENDING_TRIALS_PG` environment variable to the desired maximum number of concurrent pending trials.
# ╭────────────────────────────────────────────────────────╮
# │ Configuration for experiment     换个写法试试          │
# ├────────────────────────────────────────────────────────┤
# │ Search algorithm                 BasicVariantGenerator │
# │ Scheduler                        FIFOScheduler         │
# │ Number of trials                 1                     │
# ╰────────────────────────────────────────────────────────╯
#
# View detailed results here: /mnt/data/nfs/ray-results/mengfan/换个写法试试
# To visualize your results with TensorBoard, run: `tensorboard --logdir /tmp/ray/session_2025-12-12_04-05-19_523183_1700493/artifacts/2025-12-15_06-19-02/换个写法试试/driver_artifacts`
#
# Trial status: 1 PENDING
# Current time: 2025-12-15 06:19:02. Total running time: 0s
# Logical resource usage: 0/256 CPUs, 0/16 GPUs (0.0/2.0 accelerator_type:G)
# ╭─────────────────────────────────────────────╮
# │ Trial name              status       epochs │
# ├─────────────────────────────────────────────┤
# │ trainable_dc4f9_00000   PENDING         100 │
# ╰─────────────────────────────────────────────╯
#
# Trial trainable_dc4f9_00000 started with configuration:
# ╭─────────────────────────────────────────────────────╮
# │ Trial trainable_dc4f9_00000 config                  │
# ├─────────────────────────────────────────────────────┤
# │ epochs                                          100 │
# │ experiment_name                        换个写法试试 │
# ╰─────────────────────────────────────────────────────╯
# (trainable pid=1477970, ip=10.11.0.10)
#   0%|          | 0.00/9.91M [00:00<?, ?B/s]
# (trainable pid=1477970, ip=10.11.0.10)
#   0%|          | 32.8k/9.91M [00:00<01:28, 112kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#   1%|          | 65.5k/9.91M [00:00<01:28, 111kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#   1%|▏         | 131k/9.91M [00:00<01:05, 150kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#   3%|▎         | 262k/9.91M [00:01<00:37, 257kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#   3%|▎         | 328k/9.91M [00:01<00:36, 264kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#   4%|▍         | 426k/9.91M [00:01<00:27, 349kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#   5%|▌         | 524k/9.91M [00:01<00:22, 415kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#   6%|▋         | 623k/9.91M [00:01<00:19, 470kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#   7%|▋         | 721k/9.91M [00:02<00:17, 520kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#   8%|▊         | 819k/9.91M [00:02<00:16, 556kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#   9%|▉         | 918k/9.91M [00:02<00:16, 557kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  10%|█         | 1.02M/9.91M [00:02<00:14, 606kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  12%|█▏        | 1.15M/9.91M [00:02<00:12, 679kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  13%|█▎        | 1.25M/9.91M [00:02<00:13, 659kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  14%|█▍        | 1.38M/9.91M [00:03<00:11, 724kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  15%|█▌        | 1.51M/9.91M [00:03<00:11, 750kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  16%|█▌        | 1.61M/9.91M [00:03<00:11, 717kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  18%|█▊        | 1.74M/9.91M [00:03<00:09, 844kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  19%|█▊        | 1.84M/9.91M [00:03<00:09, 814kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  20%|█▉        | 1.93M/9.91M [00:03<00:10, 769kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  21%|██        | 2.06M/9.91M [00:03<00:09, 853kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  22%|██▏       | 2.16M/9.91M [00:03<00:08, 862kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  23%|██▎       | 2.29M/9.91M [00:04<00:08, 857kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  24%|██▍       | 2.39M/9.91M [00:04<00:09, 793kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  26%|██▌       | 2.59M/9.91M [00:04<00:07, 945kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  27%|██▋       | 2.69M/9.91M [00:04<00:07, 942kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  28%|██▊       | 2.82M/9.91M [00:04<00:07, 970kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  30%|██▉       | 2.95M/9.91M [00:04<00:06, 1.02MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  31%|███       | 3.08M/9.91M [00:04<00:06, 1.05MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  32%|███▏      | 3.21M/9.91M [00:05<00:06, 986kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  34%|███▎      | 3.34M/9.91M [00:05<00:07, 932kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  36%|███▌      | 3.54M/9.91M [00:05<00:06, 1.04MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  38%|███▊      | 3.74M/9.91M [00:05<00:05, 1.13MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  39%|███▉      | 3.87M/9.91M [00:05<00:05, 1.03MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  41%|████▏     | 4.10M/9.91M [00:05<00:04, 1.18MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  43%|████▎     | 4.29M/9.91M [00:05<00:04, 1.21MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  45%|████▍     | 4.46M/9.91M [00:06<00:04, 1.16MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  47%|████▋     | 4.69M/9.91M [00:06<00:04, 1.25MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  49%|████▉     | 4.88M/9.91M [00:06<00:03, 1.26MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  51%|█████     | 5.08M/9.91M [00:06<00:03, 1.29MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  54%|█████▍    | 5.34M/9.91M [00:06<00:03, 1.39MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  56%|█████▌    | 5.54M/9.91M [00:06<00:03, 1.38MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  58%|█████▊    | 5.73M/9.91M [00:07<00:03, 1.36MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  61%|██████    | 6.03M/9.91M [00:07<00:02, 1.50MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  63%|██████▎   | 6.26M/9.91M [00:07<00:02, 1.51MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  65%|██████▌   | 6.49M/9.91M [00:07<00:02, 1.53MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  68%|██████▊   | 6.78M/9.91M [00:07<00:01, 1.60MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  71%|███████   | 7.01M/9.91M [00:07<00:01, 1.71MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  73%|███████▎  | 7.21M/9.91M [00:07<00:01, 1.68MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  75%|███████▍  | 7.41M/9.91M [00:07<00:01, 1.70MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  77%|███████▋  | 7.60M/9.91M [00:08<00:01, 1.68MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  79%|███████▉  | 7.86M/9.91M [00:08<00:01, 1.74MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  82%|████████▏ | 8.13M/9.91M [00:08<00:01, 1.72MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  85%|████████▌ | 8.45M/9.91M [00:08<00:00, 1.85MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  88%|████████▊ | 8.68M/9.91M [00:08<00:00, 1.93MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  90%|████████▉ | 8.91M/9.91M [00:08<00:00, 1.89MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  92%|█████████▏| 9.14M/9.91M [00:08<00:00, 1.93MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  95%|█████████▍| 9.40M/9.91M [00:09<00:00, 2.01MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  97%|█████████▋| 9.63M/9.91M [00:09<00:00, 2.06MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
# 100%|█████████▉| 9.90M/9.91M [00:09<00:00, 2.11MB/s]
# 100%|██████████| 9.91M/9.91M [00:09<00:00, 1.07MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#   0%|          | 0.00/28.9k [00:00<?, ?B/s]
# (trainable pid=1477970, ip=10.11.0.10)
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 138kB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 137kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#   0%|          | 0.00/1.65M [00:00<?, ?B/s]
# (trainable pid=1477970, ip=10.11.0.10)
#   2%|▏         | 32.8k/1.65M [00:00<00:11, 135kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#   4%|▍         | 65.5k/1.65M [00:00<00:11, 133kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#   8%|▊         | 131k/1.65M [00:00<00:07, 201kB/s]
#
# Trial status: 1 RUNNING
# Current time: 2025-12-15 06:19:33. Total running time: 30s
# Logical resource usage: 1.0/256 CPUs, 0.0625/16 GPUs (0.0/2.0 accelerator_type:G)
# ╭─────────────────────────────────────────────╮
# │ Trial name              status       epochs │
# ├─────────────────────────────────────────────┤
# │ trainable_dc4f9_00000   RUNNING         100 │
# ╰─────────────────────────────────────────────╯
# (trainable pid=1477970, ip=10.11.0.10)
#  14%|█▍        | 229k/1.65M [00:00<00:04, 290kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  30%|██▉       | 492k/1.65M [00:01<00:01, 582kB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  60%|█████▉    | 983k/1.65M [00:01<00:00, 1.35MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  74%|███████▎  | 1.21M/1.65M [00:01<00:00, 1.35MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#  99%|█████████▉| 1.64M/1.65M [00:01<00:00, 1.93MB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.05MB/s]
# (trainable pid=1477970, ip=10.11.0.10)
#   0%|          | 0.00/4.54k [00:00<?, ?B/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 2.77MB/s]
# Trial status: 1 RUNNING
# Current time: 2025-12-15 06:20:03. Total running time: 1min 0s
# Logical resource usage: 1.0/256 CPUs, 0.0625/16 GPUs (0.0/2.0 accelerator_type:G)
# ╭─────────────────────────────────────────────╮
# │ Trial name              status       epochs │
# ├─────────────────────────────────────────────┤
# │ trainable_dc4f9_00000   RUNNING         100 │
# ╰─────────────────────────────────────────────╯
# Trial status: 1 RUNNING
# Current time: 2025-12-15 06:20:33. Total running time: 1min 30s
# Logical resource usage: 1.0/256 CPUs, 0.0625/16 GPUs (0.0/2.0 accelerator_type:G)
# ╭─────────────────────────────────────────────╮
# │ Trial name              status       epochs │
# ├─────────────────────────────────────────────┤
# │ trainable_dc4f9_00000   RUNNING         100 │
# ╰─────────────────────────────────────────────╯
# Trial status: 1 RUNNING
# Current time: 2025-12-15 06:21:03. Total running time: 2min 0s
# Logical resource usage: 1.0/256 CPUs, 0.0625/16 GPUs (0.0/2.0 accelerator_type:G)
# ╭─────────────────────────────────────────────╮
# │ Trial name              status       epochs │
# ├─────────────────────────────────────────────┤
# │ trainable_dc4f9_00000   RUNNING         100 │
# ╰─────────────────────────────────────────────╯
# Trial status: 1 RUNNING
# Current time: 2025-12-15 06:21:33. Total running time: 2min 30s
# Logical resource usage: 1.0/256 CPUs, 0.0625/16 GPUs (0.0/2.0 accelerator_type:G)
# ╭─────────────────────────────────────────────╮
# │ Trial name              status       epochs │
# ├─────────────────────────────────────────────┤
# │ trainable_dc4f9_00000   RUNNING         100 │
# ╰─────────────────────────────────────────────╯
# Trial status: 1 RUNNING
# Current time: 2025-12-15 06:22:03. Total running time: 3min 0s
# Logical resource usage: 1.0/256 CPUs, 0.0625/16 GPUs (0.0/2.0 accelerator_type:G)
# ╭─────────────────────────────────────────────╮
# │ Trial name              status       epochs │
# ├─────────────────────────────────────────────┤
# │ trainable_dc4f9_00000   RUNNING         100 │
# ╰─────────────────────────────────────────────╯
# Trial status: 1 RUNNING
# Current time: 2025-12-15 06:22:33. Total running time: 3min 30s
# Logical resource usage: 1.0/256 CPUs, 0.0625/16 GPUs (0.0/2.0 accelerator_type:G)
# ╭─────────────────────────────────────────────╮
# │ Trial name              status       epochs │
# ├─────────────────────────────────────────────┤
# │ trainable_dc4f9_00000   RUNNING         100 │
# ╰─────────────────────────────────────────────╯
# Trial status: 1 RUNNING
# Current time: 2025-12-15 06:23:03. Total running time: 4min 0s
# Logical resource usage: 1.0/256 CPUs, 0.0625/16 GPUs (0.0/2.0 accelerator_type:G)
# ╭─────────────────────────────────────────────╮
# │ Trial name              status       epochs │
# ├─────────────────────────────────────────────┤
# │ trainable_dc4f9_00000   RUNNING         100 │
# ╰─────────────────────────────────────────────╯
# Trial status: 1 RUNNING
# Current time: 2025-12-15 06:23:33. Total running time: 4min 30s
# Logical resource usage: 1.0/256 CPUs, 0.0625/16 GPUs (0.0/2.0 accelerator_type:G)
# ╭─────────────────────────────────────────────╮
# │ Trial name              status       epochs │
# ├─────────────────────────────────────────────┤
# │ trainable_dc4f9_00000   RUNNING         100 │
# ╰─────────────────────────────────────────────╯
# Trial status: 1 RUNNING
# Current time: 2025-12-15 06:24:03. Total running time: 5min 0s
# Logical resource usage: 1.0/256 CPUs, 0.0625/16 GPUs (0.0/2.0 accelerator_type:G)
# ╭─────────────────────────────────────────────╮
# │ Trial name              status       epochs │
# ├─────────────────────────────────────────────┤
# │ trainable_dc4f9_00000   RUNNING         100 │
# ╰─────────────────────────────────────────────╯
# Trial status: 1 RUNNING
# Current time: 2025-12-15 06:24:33. Total running time: 5min 30s
# Logical resource usage: 1.0/256 CPUs, 0.0625/16 GPUs (0.0/2.0 accelerator_type:G)
# ╭─────────────────────────────────────────────╮
# │ Trial name              status       epochs │
# ├─────────────────────────────────────────────┤
# │ trainable_dc4f9_00000   RUNNING         100 │
# ╰─────────────────────────────────────────────╯
# Trial status: 1 RUNNING
# Current time: 2025-12-15 06:25:03. Total running time: 6min 0s
# Logical resource usage: 1.0/256 CPUs, 0.0625/16 GPUs (0.0/2.0 accelerator_type:G)
# ╭─────────────────────────────────────────────╮
# │ Trial name              status       epochs │
# ├─────────────────────────────────────────────┤
# │ trainable_dc4f9_00000   RUNNING         100 │
# ╰─────────────────────────────────────────────╯
# Trial status: 1 RUNNING
# Current time: 2025-12-15 06:25:33. Total running time: 6min 30s
# Logical resource usage: 1.0/256 CPUs, 0.0625/16 GPUs (0.0/2.0 accelerator_type:G)
# ╭─────────────────────────────────────────────╮
# │ Trial name              status       epochs │
# ├─────────────────────────────────────────────┤
# │ trainable_dc4f9_00000   RUNNING         100 │
# ╰─────────────────────────────────────────────╯
# Trial status: 1 RUNNING
# Current time: 2025-12-15 06:26:03. Total running time: 7min 0s
# Logical resource usage: 1.0/256 CPUs, 0.0625/16 GPUs (0.0/2.0 accelerator_type:G)
# ╭─────────────────────────────────────────────╮
# │ Trial name              status       epochs │
# ├─────────────────────────────────────────────┤
# │ trainable_dc4f9_00000   RUNNING         100 │
# ╰─────────────────────────────────────────────╯
# Trial status: 1 RUNNING
# Current time: 2025-12-15 06:26:33. Total running time: 7min 30s
# Logical resource usage: 1.0/256 CPUs, 0.0625/16 GPUs (0.0/2.0 accelerator_type:G)
# ╭─────────────────────────────────────────────╮
# │ Trial name              status       epochs │
# ├─────────────────────────────────────────────┤
# │ trainable_dc4f9_00000   RUNNING         100 │
# ╰─────────────────────────────────────────────╯
# Trial status: 1 RUNNING
# Current time: 2025-12-15 06:27:03. Total running time: 8min 0s
# Logical resource usage: 1.0/256 CPUs, 0.0625/16 GPUs (0.0/2.0 accelerator_type:G)
# ╭─────────────────────────────────────────────╮
# │ Trial name              status       epochs │
# ├─────────────────────────────────────────────┤
# │ trainable_dc4f9_00000   RUNNING         100 │
# ╰─────────────────────────────────────────────╯
# Trial status: 1 RUNNING
# Current time: 2025-12-15 06:27:33. Total running time: 8min 30s
# Logical resource usage: 1.0/256 CPUs, 0.0625/16 GPUs (0.0/2.0 accelerator_type:G)
# ╭─────────────────────────────────────────────╮
# │ Trial name              status       epochs │
# ├─────────────────────────────────────────────┤
# │ trainable_dc4f9_00000   RUNNING         100 │
# ╰─────────────────────────────────────────────╯
# Trial status: 1 RUNNING
# Current time: 2025-12-15 06:28:03. Total running time: 9min 0s
# Logical resource usage: 1.0/256 CPUs, 0.0625/16 GPUs (0.0/2.0 accelerator_type:G)
# ╭─────────────────────────────────────────────╮
# │ Trial name              status       epochs │
# ├─────────────────────────────────────────────┤
# │ trainable_dc4f9_00000   RUNNING         100 │
# ╰─────────────────────────────────────────────╯
# Trial status: 1 RUNNING
# Current time: 2025-12-15 06:28:33. Total running time: 9min 31s
# Logical resource usage: 1.0/256 CPUs, 0.0625/16 GPUs (0.0/2.0 accelerator_type:G)
# ╭─────────────────────────────────────────────╮
# │ Trial name              status       epochs │
# ├─────────────────────────────────────────────┤
# │ trainable_dc4f9_00000   RUNNING         100 │
# ╰─────────────────────────────────────────────╯
# Trial status: 1 RUNNING
# Current time: 2025-12-15 06:29:03. Total running time: 10min 1s
# Logical resource usage: 1.0/256 CPUs, 0.0625/16 GPUs (0.0/2.0 accelerator_type:G)
# ╭─────────────────────────────────────────────╮
# │ Trial name              status       epochs │
# ├─────────────────────────────────────────────┤
# │ trainable_dc4f9_00000   RUNNING         100 │
# ╰─────────────────────────────────────────────╯
# Trial status: 1 RUNNING
# Current time: 2025-12-15 06:29:33. Total running time: 10min 31s
# Logical resource usage: 1.0/256 CPUs, 0.0625/16 GPUs (0.0/2.0 accelerator_type:G)
# ╭─────────────────────────────────────────────╮
# │ Trial name              status       epochs │
# ├─────────────────────────────────────────────┤
# │ trainable_dc4f9_00000   RUNNING         100 │
# ╰─────────────────────────────────────────────╯
#
# Trial trainable_dc4f9_00000 completed after 1 iterations at 2025-12-15 06:29:43. Total running time: 10min 41s
# ╭──────────────────────────────────────────────────╮
# │ Trial trainable_dc4f9_00000 result               │
# ├──────────────────────────────────────────────────┤
# │ checkpoint_dir_name                              │
# │ time_this_iter_s                       638.71113 │
# │ time_total_s                           638.71113 │
# │ training_iteration                             1 │
# │ V0_fro                                   4.57093 │
# │ V1_fro                                   3.17552 │
# │ V2_fro                                   5.96481 │
# │ b0_l2                                    0.02213 │
# │ b1_l2                                    0.04678 │
# │ b2_l2                                    0.23532 │
# │ config/activation                           tanh │
# │ config/batch_size                            256 │
# │ config/damp                                  0.1 │
# │ config/epochs                                100 │
# │ config/hidden1                               256 │
# │ config/hidden2                               256 │
# │ config/lr_w                                 0.01 │
# │ config/lr_x                                 0.05 │
# │ config/steps_test                            100 │
# │ config/steps_train                            20 │
# │ config/use_bias                             True │
# │ config/weight_decay                           0. │
# │ device                                      cuda │
# │ epoch_1/test_acc                          0.3274 │
# │ epoch_10/test_acc                         0.7908 │
# │ epoch_100/test_acc                        0.8946 │
# │ epoch_11/test_acc                         0.8033 │
# │ epoch_12/test_acc                         0.8165 │
# │ epoch_13/test_acc                         0.8232 │
# │ epoch_14/test_acc                         0.8309 │
# │ epoch_15/test_acc                         0.8363 │
# │ epoch_16/test_acc                         0.8396 │
# │ epoch_17/test_acc                         0.8438 │
# │ epoch_18/test_acc                         0.8476 │
# │ epoch_19/test_acc                         0.8515 │
# │ epoch_2/test_acc                          0.5139 │
# │ epoch_20/test_acc                         0.8533 │
# │ epoch_21/test_acc                         0.8539 │
# │ epoch_22/test_acc                         0.8559 │
# │ epoch_23/test_acc                         0.8567 │
# │ epoch_24/test_acc                         0.8571 │
# │ epoch_25/test_acc                         0.8597 │
# │ epoch_26/test_acc                         0.8595 │
# │ epoch_27/test_acc                         0.8607 │
# │ epoch_28/test_acc                          0.864 │
# │ epoch_29/test_acc                         0.8653 │
# │ epoch_3/test_acc                          0.5901 │
# │ epoch_30/test_acc                         0.8643 │
# │ epoch_31/test_acc                         0.8649 │
# │ epoch_32/test_acc                         0.8643 │
# │ epoch_33/test_acc                         0.8651 │
# │ epoch_34/test_acc                         0.8665 │
# │ epoch_35/test_acc                         0.8664 │
# │ epoch_36/test_acc                         0.8659 │
# │ epoch_37/test_acc                         0.8654 │
# │ epoch_38/test_acc                         0.8632 │
# │ epoch_39/test_acc                         0.8657 │
# │ epoch_4/test_acc                          0.6192 │
# │ epoch_40/test_acc                         0.8671 │
# │ epoch_41/test_acc                         0.8637 │
# │ epoch_42/test_acc                         0.8678 │
# │ epoch_43/test_acc                         0.8678 │
# │ epoch_44/test_acc                         0.8667 │
# │ epoch_45/test_acc                         0.8671 │
# │ epoch_46/test_acc                         0.8695 │
# │ epoch_47/test_acc                         0.8702 │
# │ epoch_48/test_acc                          0.869 │
# │ epoch_49/test_acc                         0.8677 │
# │ epoch_5/test_acc                          0.6437 │
# │ epoch_50/test_acc                           0.87 │
# │ epoch_51/test_acc                         0.8686 │
# │ epoch_52/test_acc                         0.8701 │
# │ epoch_53/test_acc                          0.872 │
# │ epoch_54/test_acc                         0.8695 │
# │ epoch_55/test_acc                         0.8707 │
# │ epoch_56/test_acc                         0.8721 │
# │ epoch_57/test_acc                         0.8736 │
# │ epoch_58/test_acc                         0.8724 │
# │ epoch_59/test_acc                         0.8726 │
# │ epoch_6/test_acc                          0.6899 │
# │ epoch_60/test_acc                          0.873 │
# │ epoch_61/test_acc                          0.872 │
# │ epoch_62/test_acc                          0.875 │
# │ epoch_63/test_acc                         0.8771 │
# │ epoch_64/test_acc                         0.8761 │
# │ epoch_65/test_acc                         0.8754 │
# │ epoch_66/test_acc                          0.878 │
# │ epoch_67/test_acc                         0.8787 │
# │ epoch_68/test_acc                         0.8786 │
# │ epoch_69/test_acc                         0.8751 │
# │ epoch_7/test_acc                          0.7267 │
# │ epoch_70/test_acc                         0.8789 │
# │ epoch_71/test_acc                         0.8779 │
# │ epoch_72/test_acc                         0.8792 │
# │ epoch_73/test_acc                         0.8787 │
# │ epoch_74/test_acc                         0.8801 │
# │ epoch_75/test_acc                         0.8806 │
# │ epoch_76/test_acc                         0.8817 │
# │ epoch_77/test_acc                         0.8808 │
# │ epoch_78/test_acc                         0.8817 │
# │ epoch_79/test_acc                         0.8853 │
# │ epoch_8/test_acc                          0.7509 │
# │ epoch_80/test_acc                         0.8849 │
# │ epoch_81/test_acc                         0.8845 │
# │ epoch_82/test_acc                         0.8872 │
# │ epoch_83/test_acc                         0.8852 │
# │ epoch_84/test_acc                         0.8854 │
# │ epoch_85/test_acc                         0.8882 │
# │ epoch_86/test_acc                          0.888 │
# │ epoch_87/test_acc                         0.8888 │
# │ epoch_88/test_acc                         0.8875 │
# │ epoch_89/test_acc                         0.8905 │
# │ epoch_9/test_acc                          0.7747 │
# │ epoch_90/test_acc                         0.8881 │
# │ epoch_91/test_acc                         0.8903 │
# │ epoch_92/test_acc                          0.892 │
# │ epoch_93/test_acc                         0.8918 │
# │ epoch_94/test_acc                         0.8916 │
# │ epoch_95/test_acc                         0.8906 │
# │ epoch_96/test_acc                         0.8929 │
# │ epoch_97/test_acc                          0.895 │
# │ epoch_98/test_acc                         0.8924 │
# │ epoch_99/test_acc                         0.8956 │
# │ torch.cuda.is_available()                   True │
# ╰──────────────────────────────────────────────────╯
# 2025-12-15 06:29:43,848	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/mnt/data/nfs/ray-results/mengfan/换个写法试试' in 0.0286s.
#
# Trial status: 1 TERMINATED
# Current time: 2025-12-15 06:29:43. Total running time: 10min 41s
# Logical resource usage: 1.0/256 CPUs, 0.0625/16 GPUs (0.0/2.0 accelerator_type:G)
# ╭────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name              status         epochs     iter     total time (s)     config/batch_size     config/epochs     config/steps_train     config/steps_test │
# ├────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ trainable_dc4f9_00000   TERMINATED        100        1            638.711                   256               100                     20                   100 │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#
# [INFO]: Tailing experiment logs ended 👆👆👆
# [INFO]: Note that `plot_fn` is None, will not plot `df`, `df` is returned though in case you want to plot it yourself.

# %%
results["df"]
# Out:
#   device  torch.cuda.is_available()  config/batch_size  config/epochs  \
# 0   cuda                       True                256            100
#
#    config/steps_train  config/steps_test  config/lr_x  config/lr_w  \
# 0                  20                100         0.05         0.01
#
#    config/damp  config/hidden1  ...  epoch_99/test_acc epoch_100/test_acc  \
# 0          0.1             256  ...             0.8956             0.8946
#
#      V0_fro     b0_l2    V1_fro     b1_l2   V2_fro     b2_l2  \
# 0  4.570933  0.022131  3.175516  0.046784  5.96481  0.235318
#
#    training_iteration  config/experiment_name
# 0                   1                  换个写法试试
#
# [1 rows x 122 columns]
