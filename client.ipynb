# %% [markdown]
# This example shows how to use client to manage experiments you submitted to the cluster.

# %%
from radas import get_client  # pyright: ignore[reportMissingImports]

client = get_client(
    user_name="mengfan",
    run_with="cluster:atol-gpu-5090",
)

# %%
#client.display_experiments()

# %%
client.stop_job_by_id("2e010000")
# Out:
# True
